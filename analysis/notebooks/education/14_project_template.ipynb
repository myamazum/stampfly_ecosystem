# %% [markdown]
# # Session 14-15: 最終プロジェクト テンプレート
# # Session 14-15: Final Project Template
#
# ## プロジェクト概要 / Project Overview
#
# **プロジェクト名 / Title**: [ここにプロジェクト名を記入]
#
# **チームメンバー / Team**: [名前]
#
# **概要 / Summary**: [1-2文で説明]
#
# ## プロジェクト案 / Project Ideas
#
# | テーマ | 難易度 | 内容 |
# |--------|--------|------|
# | 精密ランディング | ★★ | ToF を使った cm 精度の着陸 |
# | 障害物回避 | ★★★ | ToF センサで前方障害物を検出・回避 |
# | 風外乱推定 | ★★★ | ESKF を拡張して風速を推定 |
# | エネルギー最適軌道 | ★★★ | バッテリー消費を最小化する経路計画 |
# | マルチドローン | ★★★★ | 2台の StampFly の協調飛行 |
# | 自動チューニング | ★★★★ | ステップ応答から自動で PID ゲインを調整 |

# %% [markdown]
# ## 1. 背景と目的 / Background and Objective
#
# [ここに記述 / Write here]

# %% [markdown]
# ## 2. 理論・手法 / Theory and Method
#
# [ここに記述 / Write here]
#
# ### 数式 / Equations
#
# $$
# \text{[数式を記入]}
# $$

# %% [markdown]
# ## 3. 実装 / Implementation

# %%
# Your implementation here
# ここに実装を記述

import numpy as np
import matplotlib.pyplot as plt
from stampfly_edu import connect_or_simulate, load_flight_log, plot_trajectory

print("Project environment ready! / プロジェクト環境準備完了！")

# %%
# Core algorithm
# コアアルゴリズム

# %% [markdown]
# ## 4. 実験結果 / Experimental Results

# %%
# Data collection and analysis
# データ収集と分析

# %% [markdown]
# ## 5. 考察 / Discussion
#
# [ここに記述 / Write here]

# %% [markdown]
# ## 6. 結論 / Conclusion
#
# [ここに記述 / Write here]

# %% [markdown]
# ## 7. 参考文献 / References
#
# | # | 文献 | URL |
# |---|------|-----|
# | 1 | | |
# | 2 | | |
